# %%
import time

if 'parsed_dask' in globals():
    start = time.time()
    count_dask = parsed_dask.count().compute()
    end = time.time()
    print(f"Dask throughput: {count_dask} logs in {end-start:.2f} seconds")
else:
    print("parsed_dask not defined. Run Dask parsing cell first.")

if 'parsed_ray' in globals():
    start = time.time()
    count_ray = len(parsed_ray)
    end = time.time()
    print(f"Ray throughput: {count_ray} logs in {end-start:.2f} seconds")
else:
    print("parsed_ray not defined. Run Ray parsing cell first.")
# Out:
# Dask throughput: Timestamp    100
# Level        100
# Message      100
# dtype: int64 logs in 0.06 seconds
# Ray throughput: 100 logs in 0.00 seconds
